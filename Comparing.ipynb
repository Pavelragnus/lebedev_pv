# %% [markdown]
# # Limma without log top

# %% [markdown]
# ![image.png](attachment:f6f125c4-e0a5-44c6-aa33-25a6a795d740.png)

# %% [markdown]
# ![image.png](attachment:27aa9b8e-1484-4de6-a917-f305ae218fb0.png)

# %% [markdown]
# ![image.png](attachment:d4ad9377-fd55-4c50-b0a7-9fcd12021758.png)

# %% [markdown]
# # Limma with log top

# %% [markdown]
# ![image.png](attachment:d55d4712-df5a-40a6-b37a-d28a15b7b28e.png)

# %% [markdown]
# ![image.png](attachment:f6dea971-00df-4cab-826a-6b79bd6b42c0.png)

# %% [markdown]
# ![image.png](attachment:cc747570-da42-41c5-991d-94ea1f096907.png)

# %% [markdown]
# # Limma2 without

# %% [markdown]
# ![image.png](attachment:0b17d9cb-db33-4318-88fd-7c18c45cd97d.png)

# %% [markdown]
# ![image.png](attachment:cbe8ce2a-9169-4999-88d3-924e719bd79e.png)

# %% [markdown]
# ![image.png](attachment:86ab4c25-78a8-4797-bf1a-05b9e68b1ddf.png)

# %% [markdown]
# # Limma2 with

# %% [markdown]
# ![image.png](attachment:cb6fe229-bb0d-4655-977d-06b5cdc2fc6b.png)

# %% [markdown]
# ![image.png](attachment:765f641f-54b3-4c60-995e-9617baf18bb4.png)

# %% [markdown]
# ![image.png](attachment:8bf2a3e4-a475-4bea-9294-512a0ee9845e.png)

# %% [markdown]
# # Limma3 without

# %% [markdown]
# ![image.png](attachment:9d315228-dac1-423a-91a6-3d85889cf8aa.png)

# %% [markdown]
# ![image.png](attachment:5692c193-7b80-401c-ba6e-16740f99b508.png)

# %% [markdown]
# ![image.png](attachment:01c5255e-929c-4dbc-a437-05b66d8f5373.png)

# %% [markdown]
# # Limma4 without - choice

# %% [markdown]
# ![image.png](attachment:4a73b651-7d1c-4c54-9fa4-a630cd997d12.png)

# %% [markdown]
# ![image.png](attachment:48e33ab6-8dc3-46a9-bcfb-389b954f3e9c.png)

# %% [markdown]
# ![image.png](attachment:54ffc0f0-4b96-4b51-a47d-f57f9dd31e6f.png)

# %% [markdown]
# ![image.png](attachment:341a0ed7-290c-44f1-86bf-6d8fa87b2d02.png)

# %% [markdown]
# # Deseq

# %% [markdown]
# ![image.png](attachment:c29af4d0-79ae-4e5c-9d88-9061852888fc.png)

# %% [markdown]
# ![image.png](attachment:6ca714d5-7a0c-4102-85dd-e3660342fd17.png)

# %% [markdown]
# ![image.png](attachment:1fbd9446-9ee4-434c-971a-4165acc7e617.png)

# %% [markdown]
# # Compare with log correction - Limma 4 without
